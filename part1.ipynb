# %% [markdown]
# ### Part 1 Benchmarking and Profiling.

# %%
import time
from PIL import Image 
import array

x1, x2, y1, y2 = -1.8, 1.8, -1.8, 1.8
c_real, c_imag = -0.62772, -.42193


def calculate_z_serial_purepython(maxiter, zs, cs):
    """Calculate output list using Julia update rule"""
    output = [0] * len(zs)
    for i in range(len(zs)):
        n = 0
        z = zs[i]
        c = cs[i]
        while abs(z) < 2 and n < maxiter:
            z = z * z + c
            n += 1
        output[i] = n
    return output


def calc_pure_python( desired_width, max_iterations):
    """Create a list of complex co-ordinates (zs) and complex parameters (cs), build Julia set and display"""
    x_step = (float(x2 - x1) / float(desired_width))
    y_step = (float(y1 - y2) / float(desired_width))
    x = []
    y = []
    ycoord = y2
    while ycoord > y1:
        y.append(ycoord)
        ycoord += y_step
    xcoord = x1
    while xcoord < x2:
        x.append(xcoord)
        xcoord += x_step

    zs = []
    cs = []
    for ycoord in y:
        for xcoord in x:
            zs.append(complex(xcoord, ycoord))
            cs.append(complex(c_real, c_imag))

    print("x:", len(x))
    print("Total:", len(zs))
    start_time = time.time()
    output = calculate_z_serial_purepython(max_iterations, zs, cs)
    end_time = time.time()
    secs = end_time - start_time
    print(calculate_z_serial_purepython.__name__ + " took", secs, "seconds")



if __name__ == "__main__":
    
    calc_pure_python( desired_width=1000, max_iterations=300)
# Out:
# x: 1000
# Total: 1000000
# calculate_z_serial_purepython took 3.6742238998413086 seconds

# %%
import time
from PIL import Image
import array
x1, x2, y1, y2 = -1.8, 1.8, -1.8, 1.8
c_real, c_imag = -0.62772, -.42193


def show_greyscale(output_raw, width, height, max_iterations):
    """Convert list to array, show using PIL"""
   
    max_iterations = float(max(output_raw))
    print(max_iterations)
    scale_factor = float(max_iterations)
    scaled = [int(o / scale_factor * 255) for o in output_raw]
    output = array.array('B', scaled)  # array of unsigned ints
    im = Image.new("L", (width, width))
    im.frombytes(output.tobytes(), "raw", "L", 0, -1)
    im.show(title="Greyscale Julia Set")

    


def show_false_greyscale(output_raw, width, height, max_iterations):
    """Convert list to array, show using PIL"""  
    assert width * height == len(output_raw)
    max_value = float(max(output_raw))
    output_raw_limited = [int(float(o) / max_value * 255) for o in output_raw]
    output_rgb = (
        (o + (256 * o) + (256 ** 2) * o) * 16 for o in output_raw_limited)  # fancier
    output_rgb = array.array('I', output_rgb)
    im = Image.new("RGB", (width, height))
    im.frombytes(output_rgb.tobytes(), "raw", "RGBX", 0, -1)
    im.show(title="False Greyscale Julia Set")
    


def calculate_z_serial_purepython(maxiter, zs, cs):
    """Calculate output list using Julia update rule"""
    output = [0] * len(zs)
    for i in range(len(zs)):
        n = 0
        z = zs[i]
        c = cs[i]
        while abs(z) < 2 and n < maxiter:
            z = z * z + c
            n += 1
        output[i] = n
    return output


def calc_pure_python( desired_width, max_iterations):
    """Create a list of complex co-ordinates (zs) and complex parameters (cs), build Julia set and display"""
    x_step = (float(x2 - x1) / float(desired_width))
    y_step = (float(y1 - y2) / float(desired_width))
    x = []
    y = []
    ycoord = y2
    while ycoord > y1:
        y.append(ycoord)
        ycoord += y_step
    xcoord = x1
    while xcoord < x2:
        x.append(xcoord)
        xcoord += x_step
    width = len(x)
    height = len(y)

    zs = []
    cs = []
    for ycoord in y:
        for xcoord in x:
            zs.append(complex(xcoord, ycoord))
            cs.append(complex(c_real, c_imag))

    print("x:", len(x))
    print("Total", len(zs))
    start_time = time.time()
    output = calculate_z_serial_purepython(max_iterations, zs, cs)
    end_time = time.time()
    secs = end_time - start_time
    print(calculate_z_serial_purepython.__name__ + " took", secs, "seconds")





if __name__ == "__main__":
    
    calc_pure_python( desired_width=1000, max_iterations=300)
# Out:
# x: 1000
# Total 1000000
# calculate_z_serial_purepython took 3.7326855659484863 seconds

# %%
import time
from functools import wraps
def timefn(function):
    @wraps(function)
    def measure_time(*args, **kwargs):
        t1 = time.time()
        result = function(*args, **kwargs)
        t2 = time.time()
        total_time = t2 - t1
        print(f"{function.__name__} took {total_time} seconds")
        return result
    return measure_time
    
@timefn
def calculate_z_serial_purepython(maxiter, zs, cs):
    output = [0] * len(zs)
    for i in range(len(zs)):
        n = 0
        z = zs[i]
        c = cs[i]
        while abs(z) < 2 and n < maxiter:
            z = z * z + c
            n += 1
        output[i] = n
    return output

# %%
if __name__ == "__main__":
    calc_pure_python(desired_width=1000, max_iterations=300)

    # %timeit -r 5 -n 10 calc_pure_python(desired_width=1000, max_iterations=300)
# Out:
# x: 1000
# Total 1000000
# calculate_z_serial_purepython took 3.7122416496276855 seconds
# calculate_z_serial_purepython took 3.712364912033081 seconds
# x: 1000
# Total 1000000
# calculate_z_serial_purepython took 3.717829942703247 seconds
# calculate_z_serial_purepython took 3.7179291248321533 seconds
# x: 1000
# Total 1000000
# calculate_z_serial_purepython took 3.6609444618225098 seconds
# calculate_z_serial_purepython took 3.661041498184204 seconds
# x: 1000
# Total 1000000
# calculate_z_serial_purepython took 3.618335008621216 seconds
# calculate_z_serial_purepython took 3.6184298992156982 seconds
# x: 1000
# Total 1000000
# calculate_z_serial_purepython took 3.7079696655273438 seconds
# calculate_z_serial_purepython took 3.70806884765625 seconds
# x: 1000
# Total 1000000
# calculate_z_serial_purepython took 3.6651437282562256 seconds
# calculate_z_serial_purepython took 3.6652255058288574 seconds
# x: 1000
# Total 1000000
# calculate_z_serial_purepython took 3.871311664581299 seconds
# calculate_z_serial_purepython took 3.871408462524414 seconds
# x: 1000
# Total 1000000
# calculate_z_serial_purepython took 3.718085765838623 seconds
# calculate_z_serial_purepython took 3.7181973457336426 seconds
# x: 1000
# Total 1000000
# calculate_z_serial_purepython took 3.7242658138275146 seconds
# calculate_z_serial_purepython took 3.7243590354919434 seconds
# x: 1000
# Total 1000000
# calculate_z_serial_purepython took 3.5812511444091797 seconds
# calculate_z_serial_purepython took 3.5813486576080322 seconds
# x: 1000
# Total 1000000
# calculate_z_serial_purepython took 3.6825618743896484 seconds
# calculate_z_serial_purepython took 3.6826961040496826 seconds
# x: 1000
# Total 1000000
# calculate_z_serial_purepython took 3.799504041671753 seconds
# calculate_z_serial_purepython took 3.799621820449829 seconds
# x: 1000
# Total 1000000
# calculate_z_serial_purepython took 3.781879186630249 seconds
# calculate_z_serial_purepython took 3.7819981575012207 seconds
# x: 1000
# Total 1000000
# calculate_z_serial_purepython took 3.737480640411377 seconds
# calculate_z_serial_purepython took 3.7375824451446533 seconds
# x: 1000
# Total 1000000
# calculate_z_serial_purepython took 3.690352439880371 seconds
# calculate_z_serial_purepython took 3.6905934810638428 seconds
# x: 1000
# Total 1000000
# calculate_z_serial_purepython took 3.7234952449798584 seconds
# calculate_z_serial_purepython took 3.723601818084717 seconds
# x: 1000
# Total 1000000
# calculate_z_serial_purepython took 3.6421308517456055 seconds
# calculate_z_serial_purepython took 3.6423072814941406 seconds
# x: 1000
# Total 1000000
# calculate_z_serial_purepython took 3.6760997772216797 seconds
# calculate_z_serial_purepython took 3.676203727722168 seconds
# x: 1000
# Total 1000000
# calculate_z_serial_purepython took 3.8494722843170166 seconds
# calculate_z_serial_purepython took 3.849574565887451 seconds
# x: 1000
# Total 1000000
# calculate_z_serial_purepython took 3.836728096008301 seconds
# calculate_z_serial_purepython took 3.8370282649993896 seconds
# x: 1000
# Total 1000000
# calculate_z_serial_purepython took 3.7203142642974854 seconds
# calculate_z_serial_purepython took 3.720409870147705 seconds
# x: 1000
# Total 1000000
# calculate_z_serial_purepython took 3.684699058532715 seconds
# calculate_z_serial_purepython took 3.6848015785217285 seconds
# x: 1000
# Total 1000000
# calculate_z_serial_purepython took 3.7534515857696533 seconds
# calculate_z_serial_purepython took 3.753558874130249 seconds
# x: 1000
# Total 1000000
# calculate_z_serial_purepython took 3.7150025367736816 seconds
# calculate_z_serial_purepython took 3.715099573135376 seconds
# x: 1000
# Total 1000000
# calculate_z_serial_purepython took 3.5739693641662598 seconds
# calculate_z_serial_purepython took 3.5740675926208496 seconds
# x: 1000
# Total 1000000
# calculate_z_serial_purepython took 3.6466357707977295 seconds
# calculate_z_serial_purepython took 3.6467344760894775 seconds
# x: 1000
# Total 1000000
# calculate_z_serial_purepython took 3.6904244422912598 seconds
# calculate_z_serial_purepython took 3.690523624420166 seconds
# x: 1000
# Total 1000000
# calculate_z_serial_purepython took 3.620840311050415 seconds
# calculate_z_serial_purepython took 3.6209371089935303 seconds
# x: 1000
# Total 1000000
# calculate_z_serial_purepython took 3.6286122798919678 seconds
# calculate_z_serial_purepython took 3.628715753555298 seconds
# x: 1000
# Total 1000000
# calculate_z_serial_purepython took 3.736015796661377 seconds
# calculate_z_serial_purepython took 3.7361443042755127 seconds
# x: 1000
# Total 1000000
# calculate_z_serial_purepython took 3.808659553527832 seconds
# calculate_z_serial_purepython took 3.8087642192840576 seconds
# x: 1000
# Total 1000000
# calculate_z_serial_purepython took 3.814361333847046 seconds
# calculate_z_serial_purepython took 3.8144924640655518 seconds
# x: 1000
# Total 1000000
# calculate_z_serial_purepython took 3.9188778400421143 seconds
# calculate_z_serial_purepython took 3.919065237045288 seconds
# x: 1000
# Total 1000000
# calculate_z_serial_purepython took 3.6032493114471436 seconds
# calculate_z_serial_purepython took 3.603344202041626 seconds
# x: 1000
# Total 1000000
# calculate_z_serial_purepython took 3.6478447914123535 seconds
# calculate_z_serial_purepython took 3.6479482650756836 seconds
# x: 1000
# Total 1000000
# calculate_z_serial_purepython took 3.5627877712249756 seconds
# calculate_z_serial_purepython took 3.5629663467407227 seconds
# x: 1000
# Total 1000000
# calculate_z_serial_purepython took 3.55704665184021 seconds
# calculate_z_serial_purepython took 3.5571439266204834 seconds
# x: 1000
# Total 1000000
# calculate_z_serial_purepython took 3.5679171085357666 seconds
# calculate_z_serial_purepython took 3.5680289268493652 seconds
# x: 1000
# Total 1000000
# calculate_z_serial_purepython took 3.658097743988037 seconds
# calculate_z_serial_purepython took 3.6581969261169434 seconds
# x: 1000
# Total 1000000
# calculate_z_serial_purepython took 3.5780885219573975 seconds
# calculate_z_serial_purepython took 3.578186273574829 seconds
# x: 1000
# Total 1000000
# calculate_z_serial_purepython took 3.6670210361480713 seconds
# calculate_z_serial_purepython took 3.6671221256256104 seconds
# x: 1000
# Total 1000000
# calculate_z_serial_purepython took 3.6337382793426514 seconds
# calculate_z_serial_purepython took 3.633840799331665 seconds
# x: 1000
# Total 1000000
# calculate_z_serial_purepython took 3.6194708347320557 seconds
# calculate_z_serial_purepython took 3.619569778442383 seconds
# x: 1000
# Total 1000000
# calculate_z_serial_purepython took 3.5577926635742188 seconds
# calculate_z_serial_purepython took 3.557891368865967 seconds
# x: 1000
# Total 1000000
# calculate_z_serial_purepython took 3.54803204536438 seconds
# calculate_z_serial_purepython took 3.5481412410736084 seconds
# x: 1000
# Total 1000000
# calculate_z_serial_purepython took 3.611663818359375 seconds
# calculate_z_serial_purepython took 3.6117746829986572 seconds
# x: 1000
# Total 1000000
# calculate_z_serial_purepython took 3.567950963973999 seconds
# calculate_z_serial_purepython took 3.568045139312744 seconds
# x: 1000
# Total 1000000
# calculate_z_serial_purepython took 3.802903890609741 seconds
# calculate_z_serial_purepython took 3.8030288219451904 seconds
# x: 1000
# Total 1000000
# calculate_z_serial_purepython took 3.751148223876953 seconds
# calculate_z_serial_purepython took 3.7512505054473877 seconds
# x: 1000
# Total 1000000
# calculate_z_serial_purepython took 3.706038475036621 seconds
# calculate_z_serial_purepython took 3.7061352729797363 seconds
# x: 1000
# Total 1000000
# calculate_z_serial_purepython took 3.6519663333892822 seconds
# calculate_z_serial_purepython took 3.6520543098449707 seconds
# 3.91 s ± 38.1 ms per loop (mean ± std. dev. of 5 runs, 10 loops each)

# %%
import cProfile
import pstats

# %%
# Create a Profile object using the cProfile class
profiler = cProfile.Profile()
profiler.enable()
calc_pure_python(desired_width=1000, max_iterations=300)
profiler.disable()


# Print the stats
stats = pstats.Stats(profiler).sort_stats('cumulative')
stats.print_stats()
# Out:
# x: 1000
# Total 1000000
# calculate_z_serial_purepython took 7.147287607192993 seconds
# calculate_z_serial_purepython took 7.1474268436431885 seconds
#          36222232 function calls in 7.601 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         2    0.000    0.000    7.645    3.823 /home/juan/Desktop/tareas/tareas/.tareasvenv/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3541(run_code)
#         2    0.000    0.000    7.645    3.823 {built-in method builtins.exec}
#         1    0.352    0.352    7.601    7.601 /tmp/ipykernel_8915/1750883067.py:51(calc_pure_python)
#         1    0.000    0.000    7.147    7.147 /tmp/ipykernel_8915/2797037332.py:4(measure_time)
#         1    5.219    5.219    7.147    7.147 /tmp/ipykernel_8915/2797037332.py:14(calculate_z_serial_purepython)
#  34219980    1.928    0.000    1.928    0.000 {built-in method builtins.abs}
#   2002000    0.101    0.000    0.101    0.000 {method 'append' of 'list' objects}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.print}
#        16    0.000    0.000    0.000    0.000 /home/juan/Desktop/tareas/tareas/.tareasvenv/lib/python3.10/site-packages/ipykernel/iostream.py:655(write)
#        16    0.000    0.000    0.000    0.000 /home/juan/Desktop/tareas/tareas/.tareasvenv/lib/python3.10/site-packages/ipykernel/iostream.py:577(_schedule_flush)
#         2    0.000    0.000    0.000    0.000 /home/juan/Desktop/tareas/tareas/.tareasvenv/lib/python3.10/site-packages/ipykernel/iostream.py:259(schedule)
#         2    0.000    0.000    0.000    0.000 /home/juan/Desktop/tareas/tareas/.tareasvenv/lib/python3.10/site-packages/zmq/sugar/socket.py:621(send)
#         2    0.000    0.000    0.000    0.000 /usr/lib/python3.10/codeop.py:117(__call__)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.compile}
#        16    0.000    0.000    0.000    0.000 /home/juan/Desktop/tareas/tareas/.tareasvenv/lib/python3.10/site-packages/ipykernel/iostream.py:505(parent_header)
#        16    0.000    0.000    0.000    0.000 /home/juan/Desktop/tareas/tareas/.tareasvenv/lib/python3.10/site-packages/ipykernel/iostream.py:550(_is_master_process)
#         2    0.000    0.000    0.000    0.000 /usr/lib/python3.10/threading.py:1169(is_alive)
#         2    0.000    0.000    0.000    0.000 /home/juan/Desktop/tareas/tareas/.tareasvenv/lib/python3.10/site-packages/traitlets/traitlets.py:676(__get__)
#         2    0.000    0.000    0.000    0.000 /usr/lib/python3.10/contextlib.py:279(helper)
#         2    0.000    0.000    0.000    0.000 /usr/lib/python3.10/threading.py:1102(_wait_for_tstate_lock)
#         2    0.000    0.000    0.000    0.000 /home/juan/Desktop/tareas/tareas/.tareasvenv/lib/python3.10/site-packages/ipykernel/iostream.py:138(_event_pipe)
#         2    0.000    0.000    0.000    0.000 /usr/lib/python3.10/contextlib.py:102(__init__)
#        16    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         2    0.000    0.000    0.000    0.000 /usr/lib/python3.10/contextlib.py:130(__enter__)
#         2    0.000    0.000    0.000    0.000 /home/juan/Desktop/tareas/tareas/.tareasvenv/lib/python3.10/site-packages/traitlets/traitlets.py:629(get)
#        16    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
#         2    0.000    0.000    0.000    0.000 /usr/lib/python3.10/contextlib.py:139(__exit__)
#        22    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         2    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 /tmp/ipykernel_8915/722386950.py:1(<module>)
#         4    0.000    0.000    0.000    0.000 /home/juan/Desktop/tareas/tareas/.tareasvenv/lib/python3.10/site-packages/IPython/core/compilerop.py:180(extra_flags)
#        16    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#        16    0.000    0.000    0.000    0.000 {method 'get' of '_contextvars.ContextVar' objects}
#         4    0.000    0.000    0.000    0.000 {built-in method time.time}
#        16    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 /home/juan/Desktop/tareas/tareas/.tareasvenv/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3493(compare)
#        16    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#         2    0.000    0.000    0.000    0.000 /home/juan/Desktop/tareas/tareas/.tareasvenv/lib/python3.10/site-packages/IPython/core/interactiveshell.py:1277(user_global_ns)
#         1    0.000    0.000    0.000    0.000 /home/juan/Desktop/tareas/tareas/.tareasvenv/lib/python3.10/site-packages/dateutil/tz/tz.py:74(utcoffset)
#         2    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         2    0.000    0.000    0.000    0.000 /usr/lib/python3.10/threading.py:553(is_set)
#         4    0.000    0.000    0.000    0.000 /usr/lib/python3.10/typing.py:1737(cast)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}

# %%
# reload because snakeviz is not available in the current namespace for some reason 
# %reload_ext snakeviz


# run snakeviz with the stats file
# !snakeviz "stats_file"
# Out:
# snakeviz web server started on 127.0.0.1:8080; enter Ctrl-C to exit
# http://127.0.0.1:8080/snakeviz/%2Fhome%2Fjuan%2FDesktop%2Ftareas%2Ftareas%2FEC5E%2FBENCHMARKING%20AND%20PROFILING%2Fstats_file
# ^C
#
# Bye!

# %% [markdown]
# ![snakeviz](snakeviz.png)

# %%
# use line_profiler to profile the function and see the time taken by each line
# %load_ext line_profiler
# %lprun -f calculate_z_serial_purepython calc_pure_python(desired_width=1000, max_iterations=300)

# use memory_profiler to profile the memory usage of the function
# %reload_ext memory_profiler 
# %memit calc_pure_python(desired_width=1000, max_iterations=300)
# Out:
# The line_profiler extension is already loaded. To reload it, use:
#   %reload_ext line_profiler
# x: 1000
# Total 1000000
# calculate_z_serial_purepython took 8.76107382774353 seconds
# calculate_z_serial_purepython took 8.761198043823242 seconds
# x: 1000
# Total 1000000
# calculate_z_serial_purepython took 3.8149495124816895 seconds
# calculate_z_serial_purepython took 3.8152689933776855 seconds
# peak memory: 163.40 MiB, increment: 85.62 MiB
# Timer unit: 1e-09 s
#
# Total time: 8.76117 s
# File: /tmp/ipykernel_8915/2797037332.py
# Function: measure_time at line 4
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      4                                               @wraps(function)
#      5                                               def measure_time(*args, **kwargs):
#      6         1        759.0    759.0      0.0          t1 = time.time()
#      7         1 8761061697.0    9e+09    100.0          result = function(*args, **kwargs)
#      8         1       2563.0   2563.0      0.0          t2 = time.time()
#      9         1        977.0    977.0      0.0          total_time = t2 - t1
#     10         1     100709.0 100709.0      0.0          print(f"{function.__name__} took {total_time} seconds")
#     11         1        130.0    130.0      0.0          return result

# %% [markdown]
# ###
